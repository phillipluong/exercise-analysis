# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

import ast

# %%
# 1. Define the base directory generically
DATA_DIR = Path('C:/Users/iamph/OneDrive/Documents/Datasets/Kaggle_Fitness_Workout_Dataset')

# 2. Safely join the path to the file
file_path = DATA_DIR / 'program_summary.csv'

df = pd.read_csv(file_path)

# %%
# 2. Safely join the path to the file
file_path = DATA_DIR / 'programs_detailed_boostcamp_kaggle_CLEAN.csv'

ex = pd.read_csv(file_path)

# %%
ex
# Out:
#                                                     title  \
# 0       Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 1       Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 2       Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 3       Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 4       Jeff Nippard’s Fundamentals, Upper&Lower Split...
# ...                                                   ...
# 167624                                 Matt Vena modified
# 167625                                 Matt Vena modified
# 167626                                 Matt Vena modified
# 167627                                 Matt Vena modified
# 167628                                 Matt Vena modified
#
#                                               description  \
# 0       Primary goal is to establish a solid strength ...
# 1       Primary goal is to establish a solid strength ...
# 2       Primary goal is to establish a solid strength ...
# ...

# %% [markdown]
# # Did I accidently delete some columns?

# %%
# 2. Safely join the path to the file
file_path = DATA_DIR / 'programs_detailed_boostcamp_kaggle.csv'

ex = pd.read_csv(file_path)

# %%
def set_mapping(s):
    if s == set(['Intermediate','Beginner']):
        s = set(['Intermediate', 'Novice', 'Beginner'])
    elif s == set(['Beginner', 'Advanced']):
        s = set(['Beginner', 'Novice', 'Intermediate', 'Advanced'])
    elif s == set(['Beginner', 'Intermediate', 'Advanced']):
        s = set(['Beginner', 'Novice', 'Intermediate', 'Advanced'])
    elif s == set(['Novice', 'Advanced']):
        s = set(['Novice', 'Intermediate', 'Advanced'])
    return s

# %%
ex['level'] = ex['level'].apply(ast.literal_eval)
ex.level = ex.level.apply(set)
ex.level = ex.level.apply(set_mapping)

# %%
titles = list(ex.title.unique())

# %%
ex[ex.title == titles[0]] # This was jeff nippard's fundamentals
# Out:
#                                                  title  \
# 613  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 614  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 615  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 616  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 617  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# ..                                                 ...
# 832  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 833  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 834  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 835  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 836  Jeff Nippard’s Fundamentals, Upper&Lower Split...
#
#                                            description  \
# 613  Primary goal is to establish a solid strength ...
# 614  Primary goal is to establish a solid strength ...
# 615  Primary goal is to establish a solid strength ...
# 616  Primary goal is to establish a solid strength ...
# ...

# %%
ex[ex.title == titles[0]].level.value_counts()
# Out:
# level
# {Beginner}                216
# {Novice, Intermediate}      8
# Name: count, dtype: int64

# %%
ex[ex.title == titles[0]].goal.value_counts()
# Out:
# goal
# ['Bodybuilding']                                           216
# ['Bodybuilding', 'Powerbuilding', 'Muscle & Sculpting']      8
# Name: count, dtype: int64

# %%
ex[ex.title == titles[0]].description[613]
# Out:
# 'Primary goal is to establish a solid strength base with specifically selected foundational exercises.'

# %% [markdown]
# ## Another exercise dataset analysis

# %%
ex[ex.title == titles[0]]
# Out:
#                               title  \
# 0    Weightlifting Mobility program
# 1    Weightlifting Mobility program
# 2    Weightlifting Mobility program
# 3    Weightlifting Mobility program
# 4    Weightlifting Mobility program
# ..                              ...
# 320  Weightlifting Mobility program
# 321  Weightlifting Mobility program
# 322  Weightlifting Mobility program
# 323  Weightlifting Mobility program
# 324  Weightlifting Mobility program
#
#                                            description  \
# 0    This program is designed to help athletes succ...
# 1    This program is designed to help athletes succ...
# 2    This program is designed to help athletes succ...
# 3    This program is designed to help athletes succ...
# 4    This program is designed to help athletes succ...
# ..                                                 ...
# 320  This program is designed to help athletes succ...
# 321  This program is designed to help athletes succ...
# ...

# %%
ex.title.unique().shape
# Out:
# (2598,)

# %%
ex[ex.reps < 0].title.unique().shape
# Out:
# (1247,)

# %%
ex[ex.reps < 0]
# Out:
#                                        title  \
# 0             Weightlifting Mobility program
# 1             Weightlifting Mobility program
# 2             Weightlifting Mobility program
# 8             Weightlifting Mobility program
# 13            Weightlifting Mobility program
# ...                                      ...
# 604607                              Bulk Arc
# 604632  Full Body Kettlebell and Run Routine
# 604633  Full Body Kettlebell and Run Routine
# 604658         Magic Knight Training Program
# 604659         Magic Knight Training Program
#
#                                               description  \
# 0       This program is designed to help athletes succ...
# 1       This program is designed to help athletes succ...
# 2       This program is designed to help athletes succ...
# 8       This program is designed to help athletes succ...
# 13      This program is designed to help athletes succ...
# ...                                                   ...
# ...

# %%
ex[ex.reps > 0]
# Out:
#                                  title  \
# 3       Weightlifting Mobility program
# 4       Weightlifting Mobility program
# 5       Weightlifting Mobility program
# 6       Weightlifting Mobility program
# 7       Weightlifting Mobility program
# ...                                ...
# 605028              Matt Vena modified
# 605029              Matt Vena modified
# 605030              Matt Vena modified
# 605031              Matt Vena modified
# 605032              Matt Vena modified
#
#                                               description  \
# 3       This program is designed to help athletes succ...
# 4       This program is designed to help athletes succ...
# 5       This program is designed to help athletes succ...
# 6       This program is designed to help athletes succ...
# 7       This program is designed to help athletes succ...
# ...                                                   ...
# 605028  Modofied version of Matt Vena program, with eq...
# ...

# %%
ex.shape
# Out:
# (605033, 16)

# %%
ex.

# %% [markdown]
# # Let's observe the progression of workout time (see if there's any varying workout times per program)

# %%
titles = list(ex.title.unique())

# %%
len(titles)
# Out:
# 1567

# %%
ex[ex.title == titles[0]] #The program level can change week-by-week...
# Out:
#                                                title  \
# 0  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 1  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 2  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 3  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 4  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 5  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 6  Jeff Nippard’s Fundamentals, Upper&Lower Split...
# 7  Jeff Nippard’s Fundamentals, Upper&Lower Split...
#
#                                          description  \
# 0  Primary goal is to establish a solid strength ...
# 1  Primary goal is to establish a solid strength ...
# 2  Primary goal is to establish a solid strength ...
# 3  Primary goal is to establish a solid strength ...
# 4  Primary goal is to establish a solid strength ...
# 5  Primary goal is to establish a solid strength ...
# 6  Primary goal is to establish a solid strength ...
# 7  Primary goal is to establish a solid strength ...
#
# ...
