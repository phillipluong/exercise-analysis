# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
import ast

# %%
# 1. Define the base directory generically
DATA_DIR = Path('C:/Users/iamph/OneDrive/Documents/Datasets/Kaggle_Fitness_Workout_Dataset')

# 2. Safely join the path to the file
file_path = DATA_DIR / 'programs_detailed_boostcamp_kaggle.csv'

# %%
df = pd.read_csv(file_path)

# %%
df['level'].astype(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['level'].astype(list)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File ~\miniconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~\miniconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File ~\miniconda3\Lib\site-packages\pandas\core\dtypes\astype.py:231, in astype_array_safe(values, dtype, copy, errors)
#     225     msg = (
#     226         f"Expected an instance of {dtype.__name__}, "
#     227         "but got the class instead. Try instantiating 'dtype'."
#     228     )
#     229     raise TypeError(msg)
# --> 231 dtype = pandas_dtype(dtype)
#     232 if isinstance(dtype, NumpyEADtype):
#     233     # Ensure we don't end up with a NumpyExtensionArray
#     234     dtype = dtype.numpy_dtype
#
# File ~\miniconda3\Lib\site-packages\pandas\core\dtypes\common.py:1684, in pandas_dtype(dtype)
#    1682     return npdtype
#    1683 elif npdtype.kind == "O":
# -> 1684     raise TypeError(f"dtype '{dtype}' not understood")
#    1686 return npdtype
#
# TypeError: dtype '<class 'list'>' not understood

# %%
df['level'].value_counts()
# Out:
# level
# ['Intermediate']                                      146494
# ['Intermediate', 'Advanced']                           69543
# ['Novice', 'Intermediate']                             63057
# ['Novice']                                             50030
# ['Beginner']                                           39277
# ['Advanced']                                           30166
# ['Beginner', 'Novice', 'Intermediate', 'Advanced']     29451
# ['Beginner', 'Novice']                                 25662
# ['Intermediate', 'Novice']                             25434
# ['Beginner', 'Novice', 'Intermediate']                 21228
# ['Novice', 'Intermediate', 'Advanced']                 15694
# ['Advanced', 'Intermediate']                           12007
# ['Novice', 'Beginner']                                 11819
# ['Intermediate', 'Advanced', 'Novice']                  7356
# ['Intermediate', 'Novice', 'Advanced']                  6437
# ['Novice', 'Intermediate', 'Beginner']                  6187
# ['Novice', 'Beginner', 'Intermediate']                  5978
# ['Beginner', 'Intermediate', 'Novice', 'Advanced']      4466
# ['Beginner', 'Intermediate']                            4390
# ['Novice', 'Intermediate', 'Advanced', 'Beginner']      3511
# []                                                      2936
# ['Intermediate', 'Novice', 'Beginner']                  2593
# ['Beginner', 'Advanced', 'Novice', 'Intermediate']      2511
# ['Intermediate', 'Beginner', 'Novice']                  2211
# ['Novice', 'Beginner', 'Intermediate', 'Advanced']      1934
# ['Advanced', 'Intermediate', 'Novice', 'Beginner']      1828
# ['Beginner', 'Intermediate', 'Novice']                  1497
# ['Advanced', 'Intermediate', 'Novice']                  1261
# ['Intermediate', 'Novice', 'Beginner', 'Advanced']      1202
# ['Intermediate', 'Novice', 'Advanced', 'Beginner']      1128
# ['Novice', 'Advanced', 'Intermediate']                  1024
# ['Novice', 'Intermediate', 'Beginner', 'Advanced']      1011
# ['Intermediate', 'Beginner']                             880
# ['Intermediate', 'Advanced', 'Beginner']                 818
# ['Intermediate', 'Advanced', 'Novice', 'Beginner']       498
# ['Beginner', 'Advanced']                                 477
# ['Beginner', 'Intermediate', 'Advanced', 'Novice']       450
# ['Beginner', 'Novice', 'Advanced', 'Intermediate']       434
# ['Beginner', 'Intermediate', 'Advanced']                 431
# ['Novice', 'Beginner', 'Advanced', 'Intermediate']       393
# ['Novice', 'Advanced']                                   375
# ['Intermediate', 'Advanced', 'Beginner', 'Novice']       364
# ['Advanced', 'Novice', 'Intermediate']                   248
# ['Advanced', 'Intermediate', 'Beginner', 'Novice']       132
# ['Novice', 'Advanced', 'Intermediate', 'Beginner']        90
# ['Intermediate', 'Beginner', 'Novice', 'Advanced']        81
# ['Advanced', 'Novice']                                    39
# Name: count, dtype: int64

# %%
df.loc[0,'level'].split(",")
# Out:
# ["['Beginner'", " 'Novice'", " 'Intermediate'", " 'Advanced']"]

# %%
df.loc[0,'level']
# Out:
# "['Beginner', 'Novice', 'Intermediate', 'Advanced']"

# %%
df['level'].apply(ast.literal_eval)
# Out:
# 0         [Beginner, Novice, Intermediate, Advanced]
# 1         [Beginner, Novice, Intermediate, Advanced]
# 2         [Beginner, Novice, Intermediate, Advanced]
# 3         [Beginner, Novice, Intermediate, Advanced]
# 4         [Beginner, Novice, Intermediate, Advanced]
#                              ...
# 605028                                [Intermediate]
# 605029                                [Intermediate]
# 605030                                [Intermediate]
# 605031                                [Intermediate]
# 605032                                [Intermediate]
# Name: level, Length: 605033, dtype: object

# %%
ast.literal_eval(df.loc[0,'level'])
# Out:
# ['Beginner', 'Novice', 'Intermediate', 'Advanced']

# %%
len(ast.literal_eval(df.loc[0,'level']))
# Out:
# 4

# %%
df.dtypes
# Out:
# title                   object
# description             object
# level                   object
# goal                    object
# equipment               object
# program_length         float64
# time_per_workout       float64
# week                   float64
# day                    float64
# number_of_exercises    float64
# exercise_name           object
# sets                   float64
# reps                   float64
# intensity              float64
# created                 object
# last_edit               object
# dtype: object

# %%
df.equipme
# Out:
#                                  title  \
# 0       Weightlifting Mobility program
# 1       Weightlifting Mobility program
# 2       Weightlifting Mobility program
# 3       Weightlifting Mobility program
# 4       Weightlifting Mobility program
# ...                                ...
# 605028              Matt Vena modified
# 605029              Matt Vena modified
# 605030              Matt Vena modified
# 605031              Matt Vena modified
# 605032              Matt Vena modified
#
#                                               description  \
# 0       This program is designed to help athletes succ...
# 1       This program is designed to help athletes succ...
# 2       This program is designed to help athletes succ...
# 3       This program is designed to help athletes succ...
# 4       This program is designed to help athletes succ...
# ...                                                   ...
# 605028  Modofied version of Matt Vena program, with eq...
# 605029  Modofied version of Matt Vena program, with eq...
# 605030  Modofied version of Matt Vena program, with eq...
# 605031  Modofied version of Matt Vena program, with eq...
# 605032  Modofied version of Matt Vena program, with eq...
#
#                                                     level  \
# 0       ['Beginner', 'Novice', 'Intermediate', 'Advanc...
# 1       ['Beginner', 'Novice', 'Intermediate', 'Advanc...
# 2       ['Beginner', 'Novice', 'Intermediate', 'Advanc...
# 3       ['Beginner', 'Novice', 'Intermediate', 'Advanc...
# 4       ['Beginner', 'Novice', 'Intermediate', 'Advanc...
# ...                                                   ...
# 605028                                   ['Intermediate']
# 605029                                   ['Intermediate']
# 605030                                   ['Intermediate']
# 605031                                   ['Intermediate']
# 605032                                   ['Intermediate']
#
#                                                      goal   equipment  \
# 0       ['Olympic Weightlifting', 'Muscle & Sculpting'...  Garage Gym
# 1       ['Olympic Weightlifting', 'Muscle & Sculpting'...  Garage Gym
# 2       ['Olympic Weightlifting', 'Muscle & Sculpting'...  Garage Gym
# 3       ['Olympic Weightlifting', 'Muscle & Sculpting'...  Garage Gym
# 4       ['Olympic Weightlifting', 'Muscle & Sculpting'...  Garage Gym
# ...                                                   ...         ...
# 605028                                  ['Powerbuilding']    Full Gym
# 605029                                  ['Powerbuilding']    Full Gym
# 605030                                  ['Powerbuilding']    Full Gym
# 605031                                  ['Powerbuilding']    Full Gym
# 605032                                  ['Powerbuilding']    Full Gym
#
#         program_length  time_per_workout  week  day  number_of_exercises  \
# 0                  7.0              50.0   1.0  1.0                 16.0
# 1                  7.0              50.0   1.0  1.0                 16.0
# 2                  7.0              50.0   1.0  1.0                 16.0
# 3                  7.0              50.0   1.0  1.0                 16.0
# 4                  7.0              50.0   1.0  1.0                 16.0
# ...                ...               ...   ...  ...                  ...
# 605028            12.0              90.0   4.0  1.0                  7.0
# 605029            12.0              90.0   4.0  1.0                  7.0
# 605030            12.0              90.0   4.0  1.0                  7.0
# 605031            12.0              90.0   4.0  1.0                  7.0
# 605032            12.0              90.0   4.0  1.0                  7.0
#
#                                exercise_name  sets   reps  intensity  \
# 0       Knee-to-wall ankle dorsiflexion test   3.0 -180.0        6.0
# 1                  Banded ankle distractions   3.0  -18.0        6.0
# 2                   Slant board calf stretch   3.0  -18.0        6.0
# 3                      Seated Tibialis Raise   3.0   15.0        6.0
# 4                        90/90 Hip Rotations   3.0    8.0        6.0
# ...                                      ...   ...    ...        ...
# 605028                       Squat (Barbell)   1.0   12.0       10.0
# 605029                 Tempo Squat (Barbell)   3.0   12.0       10.0
# 605030                Larsen Press (Barbell)   3.0   12.0       10.0
# 605031         Incline Chest Press (Machine)   3.0   12.0       10.0
# 605032                           Hammer Curl   4.0   12.0       10.0
#
#                     created            last_edit
# 0       2025-03-09 04:11:00  2025-06-23 03:31:00
# 1       2025-03-09 04:11:00  2025-06-23 03:31:00
# 2       2025-03-09 04:11:00  2025-06-23 03:31:00
# 3       2025-03-09 04:11:00  2025-06-23 03:31:00
# 4       2025-03-09 04:11:00  2025-06-23 03:31:00
# ...                     ...                  ...
# 605028  2024-09-07 07:27:00  2025-06-19 06:15:00
# 605029  2024-09-07 07:27:00  2025-06-19 06:15:00
# 605030  2024-09-07 07:27:00  2025-06-19 06:15:00
# 605031  2024-09-07 07:27:00  2025-06-19 06:15:00
# 605032  2024-09-07 07:27:00  2025-06-19 06:15:00
#
# [605033 rows x 16 columns]

# %%
df.equipment.value_counts()
# Out:
# equipment
# Full Gym         464904
# Garage Gym        97086
# At Home           29934
# Dumbbell Only     13093
# Name: count, dtype: int64

# %%
df.program_length.value_counts()
# Out:
# program_length
# 12.0    248660
# 8.0      88064
# 16.0     63788
# 18.0     40570
# 10.0     37616
# 4.0      36106
# 6.0      35578
# 5.0      13302
# 9.0      11906
# 7.0       5427
# 14.0      4854
# 3.0       4622
# 13.0      4278
# 11.0      3291
# 15.0      3041
# 1.0       2658
# 2.0        873
# 17.0       383
# Name: count, dtype: int64

# %%
df.time_per_workout.value_counts()
# Out:
# time_per_workout
# 60.0     185682
# 90.0     108814
# 70.0      89468
# 80.0      56204
# 50.0      43069
# 120.0     35508
# 40.0      29405
# 100.0     19024
# 30.0      11485
# 10.0       7452
# 20.0       4853
# 110.0      4232
# 150.0      3680
# 180.0      3183
# 140.0      1433
# 130.0       757
# 160.0       428
# 170.0       315
# 72.0         41
# Name: count, dtype: int64

# %%
df.week.value_counts()
# Out:
# week
# 1.0     68590
# 2.0     65344
# 3.0     64662
# 4.0     62590
# 5.0     53441
# 6.0     50897
# 7.0     45003
# 8.0     44173
# 9.0     33032
# 10.0    31586
# 11.0    27798
# 12.0    27219
# 13.0     7012
# 14.0     6687
# 15.0     6378
# 16.0     6131
# 17.0     2271
# 18.0     2219
# Name: count, dtype: int64

# %%
df.intensity.value_counts()
# Out:
# intensity
# 8.0     257731
# 9.0     139172
# 7.0      84348
# 6.0      74062
# 10.0     34859
# 5.0       8960
# 4.0       3207
# 3.0        948
# 2.0        946
# 1.0        713
# 0.0         87
# Name: count, dtype: int64

# %%
df.goal.value_counts()
# Out:
# goal
# ['Bodybuilding']                                                        135823
# ['Bodybuilding', 'Muscle & Sculpting']                                   65263
# ['Powerbuilding']                                                        38946
# ['Muscle & Sculpting']                                                   32579
# ['Bodybuilding', 'Powerbuilding']                                        29538
#                                                                          ...
# ['Athletics', 'Powerlifting', 'Muscle & Sculpting']                         18
# ['Muscle & Sculpting', 'Powerbuilding', 'Bodybuilding', 'Athletics']        17
# ['Bodybuilding', 'Athletics', 'Powerlifting', 'Powerbuilding']              16
# ['Bodybuilding', 'Muscle & Sculpting', 'Olympic Weightlifting']             15
# ['Muscle & Sculpting', 'Powerbuilding', 'Athletics']                        12
# Name: count, Length: 250, dtype: int64

# %%
df.exercise_name.value_counts()
# Out:
# exercise_name
# Bench Press (Barbell)         16508
# Squat (Barbell)               15979
# Leg Extension                 15456
# Lateral Raise (Dumbbell)      13408
# Lat Pulldown                  11841
#                               ...
# Overhead Extension (Cable)        1
# Low-to-High Cable Fly             1
# Tricep Pushdown                   1
# Wrist Curl Cable                  1
# Lateral Raise Seated              1
# Name: count, Length: 3213, dtype: int64

# %%
df['level'] = df['level'].apply(ast.literal_eval)

# %%
counts = df['level'].explode().value_counts()

# %%
counts
# Out:
# level
# Intermediate    444252
# Novice          297614
# Advanced        195360
# Beginner        172932
# Name: count, dtype: int64

# %%
df['goal'] = df['goal'].apply(ast.literal_eval)

# %%
df['goal'].explode().value_counts()
# Out:
# goal
# Bodybuilding              401598
# Muscle & Sculpting        217456
# Powerbuilding             209991
# Athletics                 128059
# Powerlifting              116470
# Bodyweight Fitness         76163
# Olympic Weightlifting      10420
# At-Home & Calisthenics       120
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# title                   object
# description             object
# level                   object
# goal                    object
# equipment               object
# program_length         float64
# time_per_workout       float64
# week                   float64
# day                    float64
# number_of_exercises    float64
# exercise_name           object
# sets                   float64
# reps                   float64
# intensity              float64
# created                 object
# last_edit               object
# dtype: object

# %% [markdown]
# # How many exercise programs are there?

# %%
df.title.unique()
# Out:
# array(['Weightlifting Mobility program',
#        'Lyle McDonald Routine (Strength/Hypertrophy Vers)',
#        'Jeff Nippard’s Fundamentals, Upper&Lower Split, 4x', ...,
#        'Smolov Jr Bench Press Program', '531 HARDCORE',
#        'Matt Vena modified'], dtype=object)

# %%
len(df.title.unique())
# Out:
# 2598

# %%
df.shape
# Out:
# (605033, 16)

# %% [markdown]
# ## Load the program summary for this:

# %%
# 1. Define the base directory generically
DATA_DIR = Path('C:/Users/iamph/OneDrive/Documents/Datasets/Kaggle_Fitness_Workout_Dataset')

# 2. Safely join the path to the file
file_path = DATA_DIR / 'program_summary.csv'

df = pd.read_csv(file_path)

# %%
df
# Out:
#                                                   title  \
# 0     (MASS MONSTER) High Intensity 4 Day Upper Lowe...
# 1                            (NOT MY PROGRAM)SHJ Jotaro
# 2     1 PowerLift Per Day Powerbuilding 5 Day Bro Split
# 3                         10 Week Mass Building Program
# 4                                10 week deadlift focus
# ...                                                 ...
# 2593                                                  🎧
# 2594                                   👾Reza's Routine👾
# 2595    🔥 "Upper Body Dominance: 3-Day Growth System" 🔥
# 2596                                               🙈🙉🙊🐵
# 2597                                                🥷🥷🥷
#
#                                             description  \
# 0     Build tones of muscular with this high intensi...
# 1                               Build strength and size
# 2     Based off of Andy Baker's KCS (Kingwood Streng...
# 3     This workout is designed to increase your musc...
# 4                                     Increase deadlift
# ...                                                 ...
# 2593                                         Lihaskasvu
# 2594  This is a beginner friendly routine made for m...
# 2595  "Upper Body Dominance: A science-based 3-day w...
# 2596                             Muscle Memory Training
# 2597        To become stronger without becoming “bulky”
#
#                                        level  \
# 0                           ['Intermediate']
# 1               ['Advanced', 'Intermediate']
# 2     ['Beginner', 'Novice', 'Intermediate']
# 3               ['Intermediate', 'Advanced']
# 4               ['Intermediate', 'Advanced']
# ...                                      ...
# 2593            ['Intermediate', 'Advanced']
# 2594            ['Beginner', 'Intermediate']
# 2595              ['Intermediate', 'Novice']
# 2596                        ['Intermediate']
# 2597              ['Intermediate', 'Novice']
#
#                                                    goal      equipment  \
# 0          ['Muscle & Sculpting', 'Bodyweight Fitness']       Full Gym
# 1                                      ['Bodybuilding']       Full Gym
# 2        ['Athletics', 'Powerlifting', 'Powerbuilding']       Full Gym
# 3                                     ['Powerbuilding']     Garage Gym
# 4     ['Powerbuilding', 'Powerlifting', 'Bodybuildin...       Full Gym
# ...                                                 ...            ...
# 2593                                   ['Bodybuilding']     Garage Gym
# 2594                             ['Muscle & Sculpting']  Dumbbell Only
# 2595                             ['Muscle & Sculpting']       Full Gym
# 2596                                   ['Bodybuilding']       Full Gym
# 2597                  ['Bodybuilding', 'Powerbuilding']     Garage Gym
#
#       program_length  time_per_workout  total_exercises              created  \
# 0               12.0              90.0              384  2024-01-20 10:23:00
# 1                8.0              60.0              224  2024-07-08 02:28:00
# 2                6.0              90.0              237  2025-04-23 09:21:00
# 3               10.0              70.0              280  2024-09-07 03:44:00
# 4               10.0              80.0              356  2024-12-23 03:13:00
# ...              ...               ...              ...                  ...
# 2593            12.0              90.0              228  2024-10-10 04:20:00
# 2594             1.0              60.0               60  2024-09-15 08:45:00
# 2595             6.0              60.0               96  2025-02-15 08:18:00
# 2596             8.0              90.0              211  2024-12-08 01:04:00
# 2597             9.0             100.0              216  2025-05-15 10:44:00
#
#                 last_edit
# 0     2025-06-29 12:39:00
# 1     2025-06-18 09:15:00
# 2     2025-06-18 11:55:00
# 3     2025-06-18 08:01:00
# 4     2025-06-18 12:19:00
# ...                   ...
# 2593  2025-06-18 11:32:00
# 2594  2025-06-18 07:48:00
# 2595  2025-06-18 07:48:00
# 2596  2025-06-18 11:35:00
# 2597  2025-06-18 12:08:00
#
# [2598 rows x 10 columns]

# %%
df.program_length.min()
# Out:
# np.float64(1.0)

# %%
df.program_length.max()
# Out:
# np.float64(18.0)

# %%
df[df.program_length == 18]
# Out:
#                                     title  \
# 39                     2025 Shredded Plan
# 46                    3 / Week Nid Health
# 257       AESTHETIC BEAST: The Laid Split
# 259                               AI Giro
# 286   Advanced GIRLBOSS! HLM 3X Full Body
# ...                                   ...
# 2449    Weight Loss Female 40+ 4 day/week
# 2520                    anime revenge arc
# 2538             fullbody 3x til santhosh
# 2559                                  ppl
# 2562                      secret strength
#
#                                             description  \
# 39                                        Get Shredded!
# 46                                          Body Health
# 257   This program is built for guys chasing the mos...
# 259                           Just an ai workout for me
# 286   The continuation of the Intermediate Girlboss ...
# ...                                                 ...
# 2449  Strength Training for weight loss for females ...
# 2520  “They left you broken. Now you rise—stronger, ...
# 2538                                         bliv stærk
# 2559                                          look cool
# 2562                                muscle and strength
#
#                                                   level  \
# 39                           ['Novice', 'Intermediate']
# 46    ['Novice', 'Intermediate', 'Advanced', 'Beginn...
# 257              ['Beginner', 'Novice', 'Intermediate']
# 259   ['Beginner', 'Novice', 'Intermediate', 'Advanc...
# 286                                        ['Beginner']
# ...                                                 ...
# 2449                                   ['Intermediate']
# 2520                                   ['Intermediate']
# 2538  ['Beginner', 'Novice', 'Intermediate', 'Advanc...
# 2559                             ['Beginner', 'Novice']
# 2562                       ['Intermediate', 'Advanced']
#
#                                                    goal   equipment  \
# 39    ['Bodybuilding', 'Muscle & Sculpting', 'Bodywe...    Full Gym
# 46               ['Bodybuilding', 'Muscle & Sculpting']    Full Gym
# 257   ['Athletics', 'Muscle & Sculpting', 'Bodybuild...    Full Gym
# 259                 ['Athletics', 'Bodyweight Fitness']    Full Gym
# 286                              ['Muscle & Sculpting']    Full Gym
# ...                                                 ...         ...
# 2449                  ['Bodybuilding', 'Powerbuilding']    Full Gym
# 2520  ['Bodybuilding', 'Muscle & Sculpting', 'Bodywe...    Full Gym
# 2538             ['Bodybuilding', 'Muscle & Sculpting']    Full Gym
# 2559             ['Bodybuilding', 'Muscle & Sculpting']    Full Gym
# 2562                                   ['Bodybuilding']  Garage Gym
#
#       program_length  time_per_workout  total_exercises              created  \
# 39              18.0              60.0              414  2025-03-31 11:49:00
# 46              18.0              90.0              270  2025-05-26 12:09:00
# 257             18.0              70.0              756  2025-06-13 06:55:00
# 259             18.0              70.0              414  2025-03-24 12:01:00
# 286             18.0              70.0              216  2025-05-01 02:23:00
# ...              ...               ...              ...                  ...
# 2449            18.0              40.0              396  2025-04-21 06:37:00
# 2520            18.0              70.0             1836  2025-06-12 11:59:00
# 2538            18.0              70.0              594  2025-04-08 12:37:00
# 2559            18.0              80.0              324  2025-06-13 01:27:00
# 2562            18.0              90.0              378  2025-06-22 12:17:00
#
#                 last_edit
# 39    2025-06-18 10:43:00
# 46    2025-06-18 09:06:00
# 257   2025-06-21 08:14:00
# 259   2025-06-18 12:19:00
# 286   2025-06-18 08:45:00
# ...                   ...
# 2449  2025-06-18 08:10:00
# 2520  2025-06-19 09:42:00
# 2538  2025-06-18 11:41:00
# 2559  2025-06-25 04:39:00
# 2562  2025-06-25 03:01:00
#
# [73 rows x 10 columns]

# %%
df.program_length.plot.hist(bins = 18)
plt.xticks(list(range(18)))
# Out:
# ([<matplotlib.axis.XTick at 0x215c9d30f10>,
#   <matplotlib.axis.XTick at 0x215c9de15d0>,
#   <matplotlib.axis.XTick at 0x215c9a4a5d0>,
#   <matplotlib.axis.XTick at 0x215c9be2750>,
#   <matplotlib.axis.XTick at 0x215c9c14090>,
#   <matplotlib.axis.XTick at 0x215c9c1c290>,
#   <matplotlib.axis.XTick at 0x215c9c1f690>,
#   <matplotlib.axis.XTick at 0x215c9be1a10>,
#   <matplotlib.axis.XTick at 0x215c9c29f90>,
#   <matplotlib.axis.XTick at 0x215c805a590>,
#   <matplotlib.axis.XTick at 0x215c9c22a10>,
#   <matplotlib.axis.XTick at 0x215c9af93d0>,
#   <matplotlib.axis.XTick at 0x215c9d58350>,
#   <matplotlib.axis.XTick at 0x215c81ded10>,
#   <matplotlib.axis.XTick at 0x215c9d53210>,
#   <matplotlib.axis.XTick at 0x215c9bd1f10>,
#   <matplotlib.axis.XTick at 0x215c9bd0390>,
#   <matplotlib.axis.XTick at 0x215c9bcfb50>],
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17')])

# %%
df.program_length.value_counts()
# Out:
# program_length
# 12.0    793
# 8.0     411
# 4.0     357
# 6.0     235
# 16.0    146
# 10.0    127
# 1.0     113
# 5.0     105
# 3.0      78
# 18.0     73
# 9.0      55
# 7.0      32
# 2.0      17
# 14.0     13
# 11.0     13
# 13.0     12
# 15.0      8
# 17.0      1
# Name: count, dtype: int64

# %%
df['level'] = df['level'].apply(ast.literal_eval)

# %%
df.level.explode().unique()
# Out:
# array(['Intermediate', 'Advanced', 'Beginner', 'Novice', nan],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# title               0
# description         4
# level               0
# goal                0
# equipment           1
# program_length      1
# time_per_workout    0
# total_exercises     0
# created             1
# last_edit           2
# dtype: int64

# %%
df[df.program_length.isna()]
# Out:
#      title                                        description           level  \
# 1349  Lera  Get ready to transform your physique with the ...  [Intermediate]
#
#                                      goal equipment  program_length  \
# 1349  ['Athletics', 'Muscle & Sculpting']       NaN             NaN
#
#       time_per_workout  total_exercises created last_edit
# 1349              72.0               16     NaN       NaN

# %%
df[df.description.isna()]
# Out:
#                                                   title description  \
# 72                                3 dias de hipertrofia         NaN
# 234   8 week mma strength + conditioning + mass buiding         NaN
# 2408                                  Upper/Lower/sarms         NaN
# 2555                            nSuns 5/3/1 Accessories         NaN
#
#                          level  \
# 72          [Novice, Beginner]
# 234   [Intermediate, Advanced]
# 2408    [Novice, Intermediate]
# 2555    [Novice, Intermediate]
#
#                                                    goal   equipment  \
# 72                                     ['Bodybuilding']    Full Gym
# 234   ['Bodybuilding', 'Muscle & Sculpting', 'Athlet...  Garage Gym
# 2408  ['Muscle & Sculpting', 'Athletics', 'Bodybuild...    Full Gym
# 2555                                  ['Powerbuilding']    Full Gym
#
#       program_length  time_per_workout  total_exercises              created  \
# 72               6.0              60.0              126  2025-04-08 05:40:00
# 234              8.0              60.0              109  2024-05-24 10:46:00
# 2408            16.0              90.0              576  2024-11-27 03:28:00
# 2555             1.0              50.0                8  2025-06-13 10:56:00
#
#                 last_edit
# 72    2025-06-18 11:16:00
# 234   2025-06-23 12:45:00
# 2408  2025-06-18 08:11:00
# 2555  2025-06-18 08:26:00

# %%
df.drop(1349, inplace = True) # Drop Lera -- workout program incomplete

# %%
df.shape
# Out:
# (2597, 10)

# %%
df[df.program_length.isna()]
# Out:
# Empty DataFrame
# Columns: [title, description, level, goal, equipment, program_length, time_per_workout, total_exercises, created, last_edit]
# Index: []

# %%
workout_levels = df.level.explode().unique()

# %%
test = df.level.explode() == workout_levels[2]

# %%
test[test == 1]
# Out:
# 2       True
# 8       True
# 10      True
# 11      True
# 14      True
#         ...
# 2574    True
# 2581    True
# 2586    True
# 2592    True
# 2594    True
# Name: level, Length: 737, dtype: bool

# %%
df.level.explode().value_counts()
# Out:
# level
# Intermediate    1913
# Novice          1283
# Advanced         848
# Beginner         737
# Name: count, dtype: int64

# %%
df[df.level.apply(len) == 0] # Let's ignore these for now
# Out:
#                                                   title  \
# 1394  Lyle McDonald Routine (Strength/Hypertrophy Vers)
# 1423                                Mania (Upper/Lower)
# 1520                                      Monster Bench
# 1915                             Reese Training Program
# 1952                  Rugby forward off season training
# 2172                                 Swole 5 (Advanced)
# 2321                                     Treino do Josu
# 2423                                      Viking strong
#
#                                             description level goal  \
# 1394  IMPORTANT: THIS IS NOT THE ORIGINAL LYLE MCDON...    []   []
# 1423  Mania is a 4 day per week training program tha...    []   []
# 1520                Increase your 1RM on barbell bench.    []   []
# 1915  This is Reese's premium Whaley gym Training pr...    []   []
# 1952  The purpose of this program is to build a soli...    []   []
# 2172  Same as intermediate but with more revocery in...    []   []
# 2321                                        Hipertrofia    []   []
# 2423           Gain functional strength and hypertrophy    []   []
#
#           equipment  program_length  time_per_workout  total_exercises  \
# 1394       Full Gym            12.0              90.0             1152
# 1423       Full Gym            12.0              90.0              288
# 1520       Full Gym             4.0              60.0              104
# 1915  Dumbbell Only            16.0              50.0              144
# 1952       Full Gym            12.0              90.0              388
# 2172     Garage Gym            12.0              80.0              144
# 2321       Full Gym             1.0              60.0               26
# 2423       Full Gym            12.0              60.0              208
#
#                   created            last_edit
# 1394  2025-05-16 11:23:00  2025-06-27 02:28:00
# 1423  2024-07-21 06:57:00  2025-06-18 09:11:00
# 1520  2024-01-24 12:54:00  2025-06-18 12:23:00
# 1915  2025-01-02 11:41:00  2025-06-18 11:28:00
# 1952  2024-12-16 05:13:00  2025-06-18 09:31:00
# 2172  2024-11-06 10:34:00  2025-06-18 08:49:00
# 2321  2025-01-26 10:56:00  2025-06-18 08:07:00
# 2423  2024-02-04 02:50:00  2025-06-18 09:13:00

# %%
df[df.level.apply(len) == 0].index
# Out:
# Index([1394, 1423, 1520, 1915, 1952, 2172, 2321, 2423], dtype='int64')

# %%
df.drop(df[df.level.apply(len) == 0].index, inplace = True)

# %%
df.shape
# Out:
# (2589, 10)

# %%
workout_levels = df.level.explode().unique()
df.level.explode().unique()
# Out:
# array(['Intermediate', 'Advanced', 'Beginner', 'Novice'], dtype=object)

# %%
df.level.explode().value_counts()
# Out:
# level
# Intermediate    1913
# Novice          1283
# Advanced         848
# Beginner         737
# Name: count, dtype: int64

# %%
test = df.level.explode() == 'Beginner'

# %%
test = df.level.explode() == 'Beginner'
test[test == 1].index
# Out:
# Index([   2,    8,   10,   11,   14,   17,   19,   28,   34,   35,
#        ...
#        2556, 2557, 2559, 2565, 2568, 2574, 2581, 2586, 2592, 2594],
#       dtype='int64', length=737)

# %%
list(test[test == 1].index)
# Out:
# [2,
#  8,
#  10,
#  11,
#  14,
#  17,
#  19,
#  28,
#  34,
#  35,
#  40,
#  46,
#  47,
#  48,
#  49,
#  53,
#  57,
#  58,
#  59,
#  61,
#  62,
#  64,
#  65,
#  67,
#  69,
#  71,
#  72,
#  73,
#  79,
#  81,
#  82,
#  88,
#  96,
#  98,
#  106,
#  120,
#  123,
#  124,
#  127,
#  129,
#  131,
#  135,
#  136,
#  143,
#  147,
#  152,
#  154,
#  156,
#  160,
#  164,
#  170,
#  194,
#  198,
#  200,
#  208,
#  210,
#  211,
#  220,
#  221,
#  225,
#  227,
#  231,
#  232,
#  242,
#  245,
#  251,
#  256,
#  257,
#  258,
#  259,
#  263,
#  264,
#  270,
#  273,
#  274,
#  279,
#  283,
#  286,
#  288,
#  292,
#  293,
#  295,
#  299,
#  306,
#  307,
#  310,
#  313,
#  314,
#  315,
#  322,
#  327,
#  335,
#  336,
#  337,
#  340,
#  343,
#  344,
#  347,
#  348,
#  353,
#  363,
#  367,
#  370,
#  379,
#  380,
#  381,
#  384,
#  385,
#  398,
#  402,
#  413,
#  414,
#  415,
#  420,
#  423,
#  427,
#  429,
#  430,
#  431,
#  436,
#  439,
#  440,
#  442,
#  443,
#  456,
#  458,
#  461,
#  465,
#  473,
#  475,
#  478,
#  479,
#  490,
#  491,
#  492,
#  494,
#  496,
#  500,
#  502,
#  503,
#  504,
#  505,
#  507,
#  509,
#  510,
#  517,
#  526,
#  529,
#  533,
#  535,
#  537,
#  538,
#  540,
#  541,
#  543,
#  544,
#  545,
#  547,
#  554,
#  556,
#  557,
#  568,
#  572,
#  587,
#  588,
#  594,
#  597,
#  604,
#  606,
#  609,
#  610,
#  611,
#  614,
#  615,
#  616,
#  628,
#  635,
#  639,
#  645,
#  647,
#  649,
#  655,
#  657,
#  658,
#  662,
#  663,
#  665,
#  668,
#  670,
#  676,
#  678,
#  680,
#  681,
#  688,
#  694,
#  697,
#  698,
#  704,
#  706,
#  708,
#  710,
#  714,
#  718,
#  723,
#  724,
#  725,
#  727,
#  754,
#  756,
#  760,
#  762,
#  763,
#  768,
#  770,
#  784,
#  787,
#  790,
#  792,
#  797,
#  801,
#  802,
#  803,
#  809,
#  812,
#  813,
#  822,
#  824,
#  828,
#  830,
#  833,
#  836,
#  837,
#  839,
#  842,
#  843,
#  849,
#  855,
#  858,
#  860,
#  863,
#  866,
#  869,
#  872,
#  873,
#  878,
#  879,
#  880,
#  889,
#  895,
#  897,
#  901,
#  910,
#  914,
#  917,
#  921,
#  922,
#  928,
#  929,
#  930,
#  931,
#  932,
#  935,
#  941,
#  945,
#  947,
#  952,
#  953,
#  956,
#  961,
#  963,
#  966,
#  968,
#  970,
#  974,
#  979,
#  982,
#  987,
#  990,
#  995,
#  998,
#  1002,
#  1003,
#  1008,
#  1011,
#  1015,
#  1016,
#  1017,
#  1026,
#  1030,
#  1031,
#  1035,
#  1037,
#  1038,
#  1040,
#  1041,
#  1043,
#  1045,
#  1046,
#  1053,
#  1054,
#  1056,
#  1060,
#  1065,
#  1066,
#  1069,
#  1076,
#  1079,
#  1082,
#  1091,
#  1094,
#  1096,
#  1098,
#  1106,
#  1107,
#  1110,
#  1117,
#  1119,
#  1122,
#  1125,
#  1129,
#  1130,
#  1132,
#  1140,
#  1148,
#  1151,
#  1157,
#  1158,
#  1162,
#  1165,
#  1167,
#  1168,
#  1169,
#  1175,
#  1176,
#  1177,
#  1181,
#  1184,
#  1185,
#  1190,
#  1200,
#  1208,
#  1216,
#  1222,
#  1225,
#  1229,
#  1230,
#  1231,
#  1233,
#  1234,
#  1240,
#  1244,
#  1250,
#  1251,
#  1252,
#  1256,
#  1257,
#  1263,
#  1265,
#  1266,
#  1269,
#  1274,
#  1276,
#  1279,
#  1280,
#  1282,
#  1283,
#  1286,
#  1288,
#  1289,
#  1297,
#  1298,
#  1301,
#  1304,
#  1305,
#  1310,
#  1317,
#  1323,
#  1325,
#  1327,
#  1328,
#  1333,
#  1335,
#  1336,
#  1338,
#  1339,
#  1340,
#  1342,
#  1345,
#  1353,
#  1354,
#  1356,
#  1360,
#  1363,
#  1365,
#  1373,
#  1375,
#  1378,
#  1379,
#  1381,
#  1384,
#  1386,
#  1389,
#  1393,
#  1396,
#  1398,
#  1400,
#  1401,
#  1410,
#  1411,
#  1417,
#  1419,
#  1421,
#  1426,
#  1440,
#  1441,
#  1442,
#  1444,
#  1445,
#  1448,
#  1452,
#  1457,
#  1464,
#  1472,
#  1480,
#  1482,
#  1484,
#  1486,
#  1493,
#  1494,
#  1495,
#  1499,
#  1500,
#  1515,
#  1517,
#  1518,
#  1524,
#  1528,
#  1529,
#  1532,
#  1537,
#  1542,
#  1544,
#  1547,
#  1549,
#  1550,
#  1552,
#  1565,
#  1567,
#  1570,
#  1571,
#  1575,
#  1580,
#  1585,
#  1586,
#  1587,
#  1589,
#  1590,
#  1593,
#  1596,
#  1598,
#  1599,
#  1601,
#  1605,
#  1606,
#  1617,
#  1620,
#  1628,
#  1634,
#  1635,
#  1636,
#  1638,
#  1639,
#  1641,
#  1642,
#  1646,
#  1652,
#  1655,
#  1662,
#  1663,
#  1665,
#  1666,
#  1668,
#  1674,
#  1676,
#  1678,
#  1680,
#  1681,
#  1682,
#  1688,
#  1699,
#  1700,
#  1709,
#  1717,
#  1724,
#  1728,
#  1729,
#  1734,
#  1737,
#  1739,
#  1744,
#  1749,
#  1750,
#  1751,
#  1754,
#  1755,
#  1759,
#  1760,
#  1776,
#  1779,
#  1787,
#  1788,
#  1792,
#  1794,
#  1795,
#  1805,
#  1806,
#  1809,
#  1812,
#  1814,
#  1815,
#  1817,
#  1819,
#  1820,
#  1821,
#  1823,
#  1832,
#  1834,
#  1836,
#  1839,
#  1846,
#  1848,
#  1856,
#  1857,
#  1860,
#  1862,
#  1867,
#  1871,
#  1876,
#  1877,
#  1882,
#  1890,
#  1895,
#  1899,
#  1906,
#  1912,
#  1914,
#  1918,
#  1922,
#  1928,
#  1929,
#  1932,
#  1933,
#  1936,
#  1940,
#  1941,
#  1947,
#  1948,
#  1950,
#  1955,
#  1957,
#  1958,
#  1963,
#  1968,
#  1970,
#  1981,
#  1985,
#  1989,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  2002,
#  2003,
#  2007,
#  2009,
#  2010,
#  2012,
#  2013,
#  2016,
#  2017,
#  2023,
#  2024,
#  2029,
#  2035,
#  2038,
#  2040,
#  2041,
#  2046,
#  2051,
#  2058,
#  2059,
#  2067,
#  2068,
#  2070,
#  2076,
#  2078,
#  2080,
#  2085,
#  2087,
#  2088,
#  2090,
#  2091,
#  2099,
#  2104,
#  2106,
#  2107,
#  2112,
#  2113,
#  2114,
#  2125,
#  2132,
#  2133,
#  2136,
#  2137,
#  2149,
#  2151,
#  2154,
#  2156,
#  2168,
#  2178,
#  2180,
#  2196,
#  2197,
#  2206,
#  2211,
#  2214,
#  2218,
#  2219,
#  2223,
#  2226,
#  2227,
#  2228,
#  2231,
#  2234,
#  2235,
#  2240,
#  2243,
#  2246,
#  2248,
#  2252,
#  2256,
#  2257,
#  2264,
#  2267,
#  2270,
#  2274,
#  2277,
#  2282,
#  2283,
#  2284,
#  2288,
#  2292,
#  2293,
#  2296,
#  2299,
#  2302,
#  2304,
#  2307,
#  2311,
#  2316,
#  2323,
#  2326,
#  2328,
#  2329,
#  2337,
#  2338,
#  2343,
#  2344,
#  2345,
#  2351,
#  2352,
#  2365,
#  2370,
#  2378,
#  2384,
#  2387,
#  2391,
#  2396,
#  2397,
#  2400,
#  2401,
#  2403,
#  2409,
#  2411,
#  2413,
#  2414,
#  2415,
#  2416,
#  2417,
#  2418,
#  2436,
#  2439,
#  2440,
#  2441,
#  2443,
#  2451,
#  2455,
#  2456,
#  2457,
#  2458,
#  2459,
#  2466,
#  2470,
#  2471,
#  2472,
#  2473,
#  2477,
#  2486,
#  2493,
#  2496,
#  2501,
#  2503,
#  2507,
#  2509,
#  2512,
#  2518,
#  2523,
#  2526,
#  2529,
#  2533,
#  2535,
#  2536,
#  2538,
#  2542,
#  2545,
#  2547,
#  2556,
#  2557,
#  2559,
#  2565,
#  2568,
#  2574,
#  2581,
#  2586,
#  2592,
#  2594]

# %%
df.loc[list(test[test == 1].index),:]
# Out:
#                                                   title  \
# 2     1 PowerLift Per Day Powerbuilding 5 Day Bro Split
# 8                                          109273941442
# 10                               12 WEEK FAT DESTROYER.
# 11                                     12 Week Amped Up
# 14                  12 Week Women’s Bikini Body Program
# ...                                                 ...
# 2574                                   upper lower +box
# 2581                                     yates (marcus)
# 2586                                              ∩^ω^∩
# 2592                                            𝕮𝖍𝖎𝖒𝖊𝖗𝖆
# 2594                                   👾Reza's Routine👾
#
#                                             description  \
# 2     Based off of Andy Baker's KCS (Kingwood Streng...
# 8     Develop hypertrophy with minimal equipment wit...
# 10                           Burn fat and build muscle.
# 11    The JR 12-Week Bodybuilding Plan is designed t...
# 14    This program isn’t just about looking good in ...
# ...                                                 ...
# 2574                                             strong
# 2581                            high intensity programm
# 2586  Intermediate program : lower in volume than ot...
# 2592  • A mixture of fullbody, upper-lower and a bro...
# 2594  This is a beginner friendly routine made for m...
#
#                                            level  \
# 2               [Beginner, Novice, Intermediate]
# 8                             [Novice, Beginner]
# 10                            [Beginner, Novice]
# 11                            [Novice, Beginner]
# 14                            [Beginner, Novice]
# ...                                          ...
# 2574  [Novice, Beginner, Intermediate, Advanced]
# 2581  [Beginner, Novice, Intermediate, Advanced]
# 2586                                  [Beginner]
# 2592  [Advanced, Intermediate, Novice, Beginner]
# 2594                    [Beginner, Intermediate]
#
#                                                    goal      equipment  \
# 2        ['Athletics', 'Powerlifting', 'Powerbuilding']       Full Gym
# 8                                      ['Bodybuilding']        At Home
# 10                    ['Powerlifting', 'Powerbuilding']       Full Gym
# 11                                     ['Bodybuilding']       Full Gym
# 14                        ['Powerlifting', 'Athletics']       Full Gym
# ...                                                 ...            ...
# 2574                                   ['Bodybuilding']     Garage Gym
# 2581  ['Athletics', 'Bodybuilding', 'Powerlifting', ...       Full Gym
# 2586                ['Muscle & Sculpting', 'Athletics']       Full Gym
# 2592                                   ['Bodybuilding']       Full Gym
# 2594                             ['Muscle & Sculpting']  Dumbbell Only
#
#       program_length  time_per_workout  total_exercises              created  \
# 2                6.0              90.0              237  2025-04-23 09:21:00
# 8                1.0              30.0               21  2024-06-25 04:46:00
# 10              12.0              40.0              288  2024-05-15 12:34:00
# 11              12.0              60.0              450  2025-03-06 02:16:00
# 14              12.0              70.0              264  2025-02-05 12:09:00
# ...              ...               ...              ...                  ...
# 2574            16.0              60.0              384  2025-02-23 06:07:00
# 2581            16.0              60.0              560  2025-02-04 06:22:00
# 2586             4.0              70.0              100  2024-07-21 10:07:00
# 2592            12.0              70.0              264  2024-07-04 03:13:00
# 2594             1.0              60.0               60  2024-09-15 08:45:00
#
#                 last_edit
# 2     2025-06-18 11:55:00
# 8     2025-06-18 11:17:00
# 10    2025-06-23 01:00:00
# 11    2025-06-18 10:25:00
# 14    2025-06-26 12:18:00
# ...                   ...
# 2574  2025-06-18 11:30:00
# 2581  2025-06-18 11:08:00
# 2586  2025-06-18 07:58:00
# 2592  2025-06-18 09:17:00
# 2594  2025-06-18 07:48:00
#
# [737 rows x 10 columns]

# %%
df.loc[list(test[test == 1].index),:].program_length.plot.hist(bins = 18)
plt.xticks(list(range(18)))
# Out:
# ([<matplotlib.axis.XTick at 0x215ca115b10>,
#   <matplotlib.axis.XTick at 0x215ca68ec90>,
#   <matplotlib.axis.XTick at 0x215ca6afa10>,
#   <matplotlib.axis.XTick at 0x215ca6ffbd0>,
#   <matplotlib.axis.XTick at 0x215ca712090>,
#   <matplotlib.axis.XTick at 0x215ca68de90>,
#   <matplotlib.axis.XTick at 0x215ca01e290>,
#   <matplotlib.axis.XTick at 0x215c9a0a210>,
#   <matplotlib.axis.XTick at 0x215ca64d350>,
#   <matplotlib.axis.XTick at 0x215ca6b9b10>,
#   <matplotlib.axis.XTick at 0x215ca64ff90>,
#   <matplotlib.axis.XTick at 0x215ca662a90>,
#   <matplotlib.axis.XTick at 0x215ca6522d0>,
#   <matplotlib.axis.XTick at 0x215ca010150>,
#   <matplotlib.axis.XTick at 0x215ca5c8690>,
#   <matplotlib.axis.XTick at 0x215ca2638d0>,
#   <matplotlib.axis.XTick at 0x215c9c216d0>,
#   <matplotlib.axis.XTick at 0x215ca710d50>],
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17')])

# %%
test = df.level.explode() == 'Beginner'
test[test == 1].index
df.loc[list(test[test == 1].index),:].program_length.value_counts().sort_index()
# Out:
# program_length
# 1.0      36
# 2.0       6
# 3.0      20
# 4.0      91
# 5.0      29
# 6.0      74
# 7.0       4
# 8.0     116
# 9.0      18
# 10.0     36
# 11.0      6
# 12.0    226
# 13.0      7
# 14.0      4
# 15.0      2
# 16.0     44
# 18.0     18
# Name: count, dtype: int64

# %%
test = df.level.explode() == 'Beginner'
test[test == 1].index
df.loc[list(test[test == 1].index),:].program_length.value_counts().sort_index()
# Out:
# program_length
# 1.0      36
# 2.0       6
# 3.0      20
# 4.0      91
# 5.0      29
# 6.0      74
# 7.0       4
# 8.0     116
# 9.0      18
# 10.0     36
# 11.0      6
# 12.0    226
# 13.0      7
# 14.0      4
# 15.0      2
# 16.0     44
# 18.0     18
# Name: count, dtype: int64

# %%
df.loc[list(test[test == 1].index),:].program_length.value_counts().sort_index()/len(test[test == 1])
# Out:
# program_length
# 1.0     0.048847
# 2.0     0.008141
# 3.0     0.027137
# 4.0     0.123474
# 5.0     0.039349
# 6.0     0.100407
# 7.0     0.005427
# 8.0     0.157395
# 9.0     0.024423
# 10.0    0.048847
# 11.0    0.008141
# 12.0    0.306649
# 13.0    0.009498
# 14.0    0.005427
# 15.0    0.002714
# 16.0    0.059701
# 18.0    0.024423
# Name: count, dtype: float64

# %%
test = df.level.explode() == 'Novice'
test[test == 1].index
df.loc[list(test[test == 1].index),:].program_length.value_counts().sort_index()
# Out:
# program_length
# 1.0      59
# 2.0      10
# 3.0      34
# 4.0     168
# 5.0      47
# 6.0     130
# 7.0      15
# 8.0     215
# 9.0      24
# 10.0     60
# 11.0      6
# 12.0    376
# 13.0      8
# 14.0      5
# 15.0      4
# 16.0     79
# 18.0     43
# Name: count, dtype: int64

# %%
df.loc[list(test[test == 1].index),:].program_length.value_counts().sort_index()/len(test[test == 1])
# Out:
# program_length
# 1.0     0.045986
# 2.0     0.007794
# 3.0     0.026500
# 4.0     0.130943
# 5.0     0.036633
# 6.0     0.101325
# 7.0     0.011691
# 8.0     0.167576
# 9.0     0.018706
# 10.0    0.046765
# 11.0    0.004677
# 12.0    0.293063
# 13.0    0.006235
# 14.0    0.003897
# 15.0    0.003118
# 16.0    0.061574
# 18.0    0.033515
# Name: count, dtype: float64

# %%
test = df.level.explode() == 'Intermediate'
test[test == 1].index
df.loc[list(test[test == 1].index),:].program_length.value_counts().sort_index()
# Out:
# program_length
# 1.0      83
# 2.0      11
# 3.0      59
# 4.0     264
# 5.0      76
# 6.0     176
# 7.0      26
# 8.0     305
# 9.0      39
# 10.0    100
# 11.0      8
# 12.0    581
# 13.0      9
# 14.0      8
# 15.0      6
# 16.0    108
# 17.0      1
# 18.0     53
# Name: count, dtype: int64

# %%
df.loc[list(test[test == 1].index),:].program_length.value_counts().sort_index()/len(test[test == 1])
# Out:
# program_length
# 1.0     0.043387
# 2.0     0.005750
# 3.0     0.030842
# 4.0     0.138003
# 5.0     0.039728
# 6.0     0.092002
# 7.0     0.013591
# 8.0     0.159435
# 9.0     0.020387
# 10.0    0.052274
# 11.0    0.004182
# 12.0    0.303711
# 13.0    0.004705
# 14.0    0.004182
# 15.0    0.003136
# 16.0    0.056456
# 17.0    0.000523
# 18.0    0.027705
# Name: count, dtype: float64

# %%
test = df.level.explode() == 'Advanced'
test[test == 1].index
df.loc[list(test[test == 1].index),:].program_length.value_counts().sort_index()
# Out:
# program_length
# 1.0      34
# 2.0       3
# 3.0      28
# 4.0     122
# 5.0      32
# 6.0      84
# 7.0       9
# 8.0     135
# 9.0      12
# 10.0     43
# 11.0      4
# 12.0    255
# 13.0      3
# 14.0      1
# 15.0      3
# 16.0     54
# 17.0      1
# 18.0     25
# Name: count, dtype: int64

# %%
df.loc[list(test[test == 1].index),:].program_length.value_counts().sort_index()/len(test[test == 1])
# Out:
# program_length
# 1.0     0.040094
# 2.0     0.003538
# 3.0     0.033019
# 4.0     0.143868
# 5.0     0.037736
# 6.0     0.099057
# 7.0     0.010613
# 8.0     0.159198
# 9.0     0.014151
# 10.0    0.050708
# 11.0    0.004717
# 12.0    0.300708
# 13.0    0.003538
# 14.0    0.001179
# 15.0    0.003538
# 16.0    0.063679
# 17.0    0.001179
# 18.0    0.029481
# Name: count, dtype: float64

# %%
df.count()
# Out:
# title               2589
# description         2585
# level               2589
# goal                2589
# equipment           2589
# program_length      2589
# time_per_workout    2589
# total_exercises     2589
# created             2589
# last_edit           2588
# dtype: int64

# %%
df.equipment.value_counts()
# Out:
# equipment
# Full Gym         1842
# Garage Gym        560
# At Home           119
# Dumbbell Only      68
# Name: count, dtype: int64

# %%
df.time_per_workout.min()
# Out:
# np.float64(10.0)

# %%
df.time_per_workout.max()
# Out:
# np.float64(180.0)

# %%
df.time_per_workout.mean()
# Out:
# np.float64(69.02356122054847)

# %%
df.time_per_workout.median()
# Out:
# np.float64(60.0)

# %%
df.time_per_workout.hist(bins = 18)
# Out:
# <Axes: >

# %%
test = df.level.explode() == 'Advanced'
test[test == 1].index
df.loc[list(test[test == 1].index),:].time_per_workout.hist(bins = 18)
# Out:
# <Axes: >

# %%
test = df.level.explode() == 'Intermediate'
test[test == 1].index
df.loc[list(test[test == 1].index),:].time_per_workout.hist(bins = 18)
# Out:
# <Axes: >

# %%
test = df.level.explode() == 'Novice'
test[test == 1].index
df.loc[list(test[test == 1].index),:].time_per_workout.hist(bins = 18)
# Out:
# <Axes: >

# %%
test = df.level.explode() == 'Beginner'
test[test == 1].index
df.loc[list(test[test == 1].index),:].time_per_workout.hist(bins = 18)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#                                                title  \
# 0  (MASS MONSTER) High Intensity 4 Day Upper Lowe...
# 1                         (NOT MY PROGRAM)SHJ Jotaro
# 2  1 PowerLift Per Day Powerbuilding 5 Day Bro Split
# 3                      10 Week Mass Building Program
# 4                             10 week deadlift focus
#
#                                          description  \
# 0  Build tones of muscular with this high intensi...
# 1                            Build strength and size
# 2  Based off of Andy Baker's KCS (Kingwood Streng...
# 3  This workout is designed to increase your musc...
# 4                                  Increase deadlift
#
#                               level  \
# 0                    [Intermediate]
# 1          [Advanced, Intermediate]
# 2  [Beginner, Novice, Intermediate]
# 3          [Intermediate, Advanced]
# 4          [Intermediate, Advanced]
#
#                                                 goal   equipment  \
# 0       ['Muscle & Sculpting', 'Bodyweight Fitness']    Full Gym
# 1                                   ['Bodybuilding']    Full Gym
# 2     ['Athletics', 'Powerlifting', 'Powerbuilding']    Full Gym
# 3                                  ['Powerbuilding']  Garage Gym
# 4  ['Powerbuilding', 'Powerlifting', 'Bodybuildin...    Full Gym
#
#    program_length  time_per_workout  total_exercises              created  \
# 0            12.0              90.0              384  2024-01-20 10:23:00
# 1             8.0              60.0              224  2024-07-08 02:28:00
# 2             6.0              90.0              237  2025-04-23 09:21:00
# 3            10.0              70.0              280  2024-09-07 03:44:00
# 4            10.0              80.0              356  2024-12-23 03:13:00
#
#              last_edit
# 0  2025-06-29 12:39:00
# 1  2025-06-18 09:15:00
# 2  2025-06-18 11:55:00
# 3  2025-06-18 08:01:00
# 4  2025-06-18 12:19:00

# %%
df['goal'] = df['goal'].apply(ast.literal_eval)

# %%
goals = df.goal.explode().unique()

# %%
df.goal.explode().value_counts(dropna=False)
# Out:
# goal
# Bodybuilding             1723
# Muscle & Sculpting        935
# Powerbuilding             905
# Athletics                 538
# Powerlifting              494
# Bodyweight Fitness        322
# Olympic Weightlifting      39
# Name: count, dtype: int64

# %%
df.level.apply(len).value_counts()
# Out:
# level
# 1    1124
# 2     940
# 3     323
# 4     202
# Name: count, dtype: int64

# %%
df.level = df.level.apply(set)

# %%
df.level[0]
# Out:
# {'Intermediate'}

# %%
{'Intermediate','Beginner'} == {'Beginner', 'Intermediate'}
# Out:
# True

# %%
def set_mapping(s):
    if s == set(['Intermediate','Beginner']):
        s = set(['Intermediate', 'Novice', 'Beginner'])
    elif s == set(['Beginner', 'Advanced']):
        s = set(['Beginner', 'Novice', 'Intermediate', 'Advanced'])
    elif s == set(['Beginner', 'Intermediate', 'Advanced']):
        s = set(['Beginner', 'Novice', 'Intermediate', 'Advanced'])
    elif s == set(['Novice', 'Advanced']):
        s = set(['Novice', 'Intermediate', 'Advanced'])
    return s

# %%
df.level = df.level.apply(set_mapping)

# %%
df.level.value_counts()
# Out:
# level
# {Intermediate}                                621
# {Novice, Intermediate}                        374
# {Intermediate, Advanced}                      366
# {Novice}                                      217
# {Beginner, Intermediate, Novice, Advanced}    208
# {Beginner, Intermediate, Novice}              196
# {Novice, Beginner}                            168
# {Beginner}                                    165
# {Novice, Intermediate, Advanced}              153
# {Advanced}                                    121
# Name: count, dtype: int64

# %%
df.level.explode().value_counts()
# Out:
# level
# Intermediate    1918
# Novice          1316
# Advanced         848
# Beginner         737
# Name: count, dtype: int64

# %% [markdown]
# # Workout Focus by level

# %%
test = df.level.explode() == 'Intermediate'
test[test == 1].index
df.loc[list(test[test == 1].index),:].goal.explode.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 test = df.level.explode() == 'Intermediate'
#       2 test[test == 1].index
#       3 df.loc[list(test[test == 1].index),:].goal.explode.value_counts()
#
# NameError: name 'df' is not defined
